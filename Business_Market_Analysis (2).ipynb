# %% [markdown]
# # Business Market Analysis
# ___

# %% [markdown]
# ## Introduction / Business Problem

# %% [markdown]
# This analysis is meant to help a business venture choose between locations. Specifically we will look at Mexican retaraunts in Los Angeles. Finding a neighborhood that is not saturated with other Mexican restaunts would be a great place to start!

# %% [markdown]
# ## Data

# %%
import numpy as np
import pandas as pd
import folium
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
import requests
import urllib.request
from urllib.request import urlopen
import time
from bs4 import BeautifulSoup
#!pip install pgeocode
import pgeocode

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Delete this cell before publishing
# </div>

# %%
# Foursquare API authentication
CLIENT_ID = '' 
CLIENT_SECRET = '' 
ACCESS_TOKEN = '' 
VERSION = '20180604'
LIMIT = 30

# %% [markdown]
# ### scrape for list of neighborhoods in LA

# %% [markdown]
# First we need to set some variables, including defining the source of our information. We will be scraping LAalminac.com to get out communities and zip codes.

# %%
url = "http://www.laalmanac.com/communications/cm02_communities.php" 
data = requests.get(url).text 
soup = BeautifulSoup(data,"html.parser")

# %% [markdown]
# Here we are creating a list, finding our cells, cleaning some unnececary characters, and appending our list.

# %%
import re

table=soup.find('table')
list_rows = []
for row in table:
    cells = soup.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [Acton, 93510, Agoura Hills, 91301, Agoura Hills (PO Boxes), 91376, Agua Dulce, 91390, Alhambra, 91801, 91803, Alhambra (Non-Geographic Zip Code Within 91801), 91804, Alhambra (PO Boxes), 91802, 91896, 91899, Altadena, 91001, Altadena (PO Boxes), 91003, Americana at Brand &amp; Glendale Galleria (Glendale), 91210, Arcadia, 91006, 91007, Arcadia (PO Boxes), 91066, 91077, Arleta (Los Angeles), 91331, Arlington Heights (Los Angeles), 90019, Artesia, 90701, Artesia (PO Boxes), 90702, Athens, 90044, Atwater Village (Los Angeles), 90039, Avalon (PO Boxes), 90704, Avocado Heights, 91746, Azusa, 91010, 91702, Baldwin Hills (Los Angeles), 90008, Baldwin Park, 91706, Bassett, 91746, Bel Air Estates (Los Angeles), 90049, Bel Air Estates, Beverly Glen (Los Angeles), 90077, Bell, 90201, 90270, Bell (PO Boxes), 90202, Bell (Shared Firms), 90096, Bell Canyon, 91307, Bell Gardens, 90201, Bell Gardens (PO Boxes), 90202, Bellflower, 90706, Bellflower (PO Boxes), 90707, Belmont Shore (Long Beach), 90803, Belmont Shore (PO Boxes) (Long Beach), 90853, Beverly Glen, Bel Air Estates (Los Angeles), 90077, Beverly Hills, 90210, 90211, 90212, Beverly Hills (PO Boxes), 90209, 90213, Biola University (La Mirada), 90639, Bixby Knolls (Long Beach), 90807, Bouquet Canyon, 91350, Box Canyon, 91304, Boyle Heights (Los Angeles), 90033, 90063, Bradbury, 91008, 91010, Brentwood (Los Angeles), 90049, Burbank, 91501, 91502, 91505, 91506, Burbank (Burbank Studios), 91522, Burbank (Glenoaks), 91504, Burbank (PO Boxes), 91503, 91507, 91508, 91510, Burbank (Walt Disney Co), 91521, 91526, Burbank Studios (Burbank), 91522, 91523, Bureau of the Census (Pomona), 91797, Byzantine-Latino Quarter (Los Angeles), 90006, Calabasas, 91302, California Institute of Technology (Pasadena), 91125, 91126, California State Univ Long Beach (Long Beach), 90840, California State Univ Northridge (Los Angeles), 91330, Camino College (Torrance), 90506, Canoga Park (Los Angeles), 91303, 91304, Canoga Park (PO Boxes) (Los Angeles), 91305, 91308, 91309, Canyon Country (PO Boxes) (Santa Clarita), 91386, Canyon Country (Santa Clarita), 91351, 91387, Carson, 90745, 90746, 90810, Carson (California State Univ Dominguez Hills), 90747, Carson (Lakeshore Learning), 90895, Carson (PO Boxes), 90749, Castaic, 91310, 91384, Castaic Valley (Santa Clarita PO), 91383, Catalina Island (PO Boxes), 90704, Castellemare (Los Angeles), 90272, Century City (Los Angeles), 90067, Cerritos, 90703, Charter Oak, 91724, Chatsworth (Los Angeles), 91311, Chatsworth (PO Boxes) (Los Angeles), 91313, Cheviot Hills (Los Angeles), 90064, Chinatown (Los Angeles), 90012, Chinatown (PO Boxes) (Los Angeles), 90030, 90086, 90087, Citibank (Los Angeles), 90189, City Ranch, 93551, City Terrace, 90063, Claremont, 91711, Commerce, City of, 90040, Commerce (PO Boxes), 90091, Commerce, East Los Angeles, 90023, Compton, 90220, 90221, 90222, 90224, Compton (PO Boxes), 90223, Cornell, 91301, Country Club Park (Los Angeles), 90019, Covina, 91722, 91723, 91724, Crenshaw (Los Angeles), 90008, Crystalaire, 93544, Cudahy, 90201, Culver City, 90066, 90230, 90232, Culver City (PO Boxes), 90231, 90233, Cypress Park (Los Angeles), 90065, Del Sur, 93536, Diamond Bar, 91765, 91789, Dominguez, 90810, Downey, 90240, 90241, 90242, Downey (PO Boxes), 90239, Downtown Arts District (Los Angeles), 90012, 90014, Downtown Bank of America (Los Angeles), 90074, Downtown Bunker Hill (Los Angeles), 90012, 90017, 90071, Downtown Bunker Hill (PO Boxes) (Los Angeles), 90081, Downtown Central (Los Angeles), 90012, 90013, Downtown City West (Los Angeles), 90017, Downtown Civic Center (Los Angeles), 90012, Downtown Civic Center (PO Boxes) (Los Angeles), 90053, Downtown Fashion District (Los Angeles), 90013, 90014, 90015, 90021, 90079, Downtown Fashion District (PO Boxes) (Los Angeles), 90055, Downtown Historic Core (Los Angeles), 90012, 90014, 90071, Downtown Little Tokyo (Los Angeles), 90012, Downtown South Park (Los Angeles), 90015, 90017, Downtown Southeast (Los Angel ...
# str

# %% [markdown]
# Next we must split the data at the commas.

# %%
s = clean2.split(',')
s
# Out:
# ['[Acton',
#  ' 93510',
#  ' Agoura Hills',
#  ' 91301',
#  ' Agoura Hills (PO Boxes)',
#  ' 91376',
#  ' Agua Dulce',
#  ' 91390',
#  ' Alhambra',
#  ' 91801',
#  ' 91803',
#  ' Alhambra (Non-Geographic Zip Code Within 91801)',
#  ' 91804',
#  ' Alhambra (PO Boxes)',
#  ' 91802',
#  ' 91896',
#  ' 91899',
#  ' Altadena',
#  ' 91001',
#  ' Altadena (PO Boxes)',
#  ' 91003',
#  ' Americana at Brand &amp; Glendale Galleria (Glendale)',
#  ' 91210',
#  ' Arcadia',
#  ' 91006',
#  ' 91007',
#  ' Arcadia (PO Boxes)',
#  ' 91066',
#  ' 91077',
#  ' Arleta (Los Angeles)',
#  ' 91331',
#  ' Arlington Heights (Los Angeles)',
#  ' 90019',
#  ' Artesia',
#  ' 90701',
#  ' Artesia (PO Boxes)',
#  ' 90702',
#  ' Athens',
#  ' 90044',
#  ' Atwater Village (Los Angeles)',
#  ' 90039',
#  ' Avalon (PO Boxes)',
#  ' 90704',
#  ' Avocado Heights',
#  ' 91746',
#  ' Azusa',
#  ' 91010',
#  ' 91702',
#  ' Baldwin Hills (Los Angeles)',
#  ' 90008',
#  ' Baldwin Park',
#  ' 91706',
#  ' Bassett',
#  ' 91746',
#  ' Bel Air Estates (Los Angeles)',
#  ' 90049',
#  ' Bel Air Estates',
#  ' Beverly Glen (Los Angeles)',
#  ' 90077',
#  ' Bell',
#  ' 90201',
#  ' 90270',
#  ' Bell (PO Boxes)',
#  ' 90202',
#  ' Bell (Shared Firms)',
#  ' 90096',
#  ' Bell Canyon',
#  ' 91307',
#  ' Bell Gardens',
#  ' 90201',
#  ' Bell Gardens (PO Boxes)',
#  ' 90202',
#  ' Bellflower',
#  ' 90706',
#  ' Bellflower (PO Boxes)',
#  ' 90707',
#  ' Belmont Shore (Long Beach)',
#  ' 90803',
#  ' Belmont Shore (PO Boxes) (Long Beach)',
#  ' 90853',
#  ' Beverly Glen',
#  ' Bel Air Estates (Los Angeles)',
#  ' 90077',
#  ' Beverly Hills',
#  ' 90210',
#  ' 90211',
#  ' 90212',
#  ' Beverly Hills (PO Boxes)',
#  ' 90209',
#  ' 90213',
#  ' Biola University (La Mirada)',
#  ' 90639',
#  ' Bixby Knolls (Long Beach)',
#  ' 90807',
#  ' Bouquet Canyon',
#  ' 91350',
#  ' Box Canyon',
#  ' 91304',
#  ' Boyle Heights (Los Angeles)',
#  ' 90033',
#  ' 90063',
#  ' Bradbury',
#  ' 91008',
#  ' 91010',
#  ' Brentwood (Los Angeles)',
#  ' 90049',
#  ' Burbank',
#  ' 91501',
#  ' 91502',
#  ' 91505',
#  ' 91506',
#  ' Burbank (Burbank Studios)',
#  ' 91522',
#  ' Burbank (Glenoaks)',
#  ' 91504',
#  ' Burbank (PO Boxes)',
#  ' 91503',
#  ' 91507',
#  ' 91508',
#  ' 91510',
#  ' Burbank (Walt Disney Co)',
#  ' 91521',
#  ' 91526',
#  ' Burbank Studios (Burbank)',
#  ' 91522',
#  ' 91523',
#  ' Bureau of the Census (Pomona)',
#  ' 91797',
#  ' Byzantine-Latino Quarter (Los Angeles)',
#  ' 90006',
#  ' Calabasas',
#  ' 91302',
#  ' California Institute of Technology (Pasadena)',
#  ' 91125',
#  ' 91126',
#  ' California State Univ Long Beach (Long Beach)',
#  ' 90840',
#  ' California State Univ Northridge (Los Angeles)',
#  ' 91330',
#  ' Camino College (Torrance)',
#  ' 90506',
#  ' Canoga Park (Los Angeles)',
#  ' 91303',
#  ' 91304',
#  ' Canoga Park (PO Boxes) (Los Angeles)',
#  ' 91305',
#  ' 91308',
#  ' 91309',
#  ' Canyon Country (PO Boxes) (Santa Clarita)',
#  ' 91386',
#  ' Canyon Country (Santa Clarita)',
#  ' 91351',
#  ' 91387',
#  ' Carson',
#  ' 90745',
#  ' 90746',
#  ' 90810',
#  ' Carson (California State Univ Dominguez Hills)',
#  ' 90747',
#  ' Carson (Lakeshore Learning)',
#  ' 90895',
#  ' Carson (PO Boxes)',
#  ' 90749',
#  ' Castaic',
#  ' 91310',
#  ' 91384',
#  ' Castaic Valley (Santa Clarita PO)',
#  ' 91383',
#  ' Catalina Island (PO Boxes)',
#  ' 90704',
#  ' Castellemare (Los Angeles)',
#  ' 90272',
#  ' Century City (Los Angeles)',
#  ' 90067',
#  ' Cerritos',
#  ' 90703',
#  ' Charter Oak',
#  ' 91724',
#  ' Chatsworth (Los Angeles)',
#  ' 91311',
#  ' Chatsworth (PO Boxes) (Los Angeles)',
#  ' 91313',
#  ' Cheviot Hills (Los Angeles)',
#  ' 90064',
#  ' Chinatown (Los Angeles)',
#  ' 90012',
#  ' Chinatown (PO Boxes) (Los Angeles)',
#  ' 90030',
#  ' 90086',
#  ' 90087',
#  ' Citibank (Los Angeles)',
#  ' 90189',
#  ' City Ranch',
#  ' 93551',
#  ' City Terrace',
#  ' 90063',
#  ' Claremont',
#  ' 91711',
#  ' Commerce',
#  ' City of',
#  ' 90040',
#  ' Commerce (PO Boxes)',
#  ' 90091',
#  ' Commerce',
#  ' East Los Angeles',
#  ' 90023',
#  ' Compton',
#  ' 90220',
#  ' 90221',
#  ' 90222',
#  ' 90224',
#  ' Compton (PO Boxes)',
#  ' 90223',
#  ' Cornell',
#  ' 91301',
#  ' Country Club Park (Los Angeles)',
#  ' 90019',
#  ' Covina',
#  ' 91722',
#  ' 91723',
#  ' 91724',
#  ' Crenshaw (Los Angeles)',
#  ' 90008',
#  ' Crystalaire',
#  ' 93544',
#  ' Cudahy',
#  ' 90201',
#  ' Culver City',
#  ' 90066',
#  ' 90230',
#  ' 90232',
#  ' Culver City (PO Boxes)',
#  ' 90231',
#  ' 90233',
#  ' Cypress Park (Los Angeles)',
#  ' 90065',
#  ' Del Sur',
#  ' 93536',
#  ' Diamond Bar',
#  ' 91765',
#  ' 91789',
#  ' Dominguez',
#  ' 90810',
#  ' Downey',
#  ' 90240',
#  ' 90241',
#  ' 90242',
#  ' Downey (PO Boxes)',
#  ' 90239',
#  ' Downtown Arts District (Los Angeles)',
#  ' 90012',
#  ' 90014',
#  ' Downtown Bank of America (Los Angeles)',
#  ' 90074',
#  ' Downtown Bunker Hill (Los Angeles)',
#  ' 90012',
#  ' 90017',
#  ' 90071',
#  ' Downtown Bunker Hill (PO Boxes) (Los Angeles)',
#  ' 90081',
#  ' Downtown Central (Los Angeles)',
#  ' 90012',
#  ' 90013',
#  ' Downtown City West (Los Angeles)',
#  ' 90017',
#  ' Downtown Civic Center (Los Angeles)',
#  ' 90012',
#  ' Downtown Civic Center (PO Boxes) (Los Angeles)',
#  ' 90053',
#  ' Downtown Fashion District (Los Angeles)',
#  ' 90013',
#  ' 90014',
#  ' 90015',
#  ' 90021',
#  ' 90079',
#  ' Downtown Fashion District (PO Boxes) (Los Angeles)',
#  ' 90055',
#  ' Downtown Historic Core (Los Angeles)',
#  ' 90012',
#  ' 90014',
#  ' 90071',
#  ' Downtown Little Tokyo (Los Angeles)',
#  ' 90012',
#  ' Downtown South Park (Los Angeles)',
#  ' 90015',
#  ' 90017',
#  ' Downtown Southeast (Los Angeles)',
#  ' 90021',
#  ' Downtown Terminal Annex (PO Boxes) (Los Angeles)',
#  ' 90086',
#  ' Duarte',
#  ' 91010',
#  ' Duarte (PO Boxes)',
#  ' 91009',
#  ' Eagle Rock (Los Angeles)',
#  ' 90041',
#  ' East Hollywood (Los Angeles)',
#  ' 90029',
#  ' East La Mirada',
#  ' 90604',
#  ' East Long Beach (Long Beach)',
#  ' 90804',
#  ' East Los Angeles',
#  ' 90022',
#  ' East Los Angeles',
#  ' City of Commerce',
#  ' 90023',
#  ' East Rancho Dominguez',
#  ' 90221',
#  ' Echo Park (Los Angeles)',
#  ' 90026',
#  ' Edwards AFB (Portion in LA County)',
#  ' 93523',
#  ' El Monte',
#  ' 91731',
#  ' 91732',
#  ' 91733',
#  ' El Monte (PO Boxes)',
#  ' 91734',
#  ' El Monte (Wells Fargo Bank)',
#  ' 91735',
#  ' El Segundo',
#  ' 90245',
#  ' El Sereno',
#  ' Monterey Hills',
#  ' University Hills (Los Angeles)',
#  ' 90032',
#  ' Elizabeth Lake',
#  ' 93532',
#  ' Elysian Valley (Los Angeles)',
#  ' 90039',
#  ' Encino (Los Angeles)',
#  ' 91316',
#  ' 91436',
#  ' Encino (PO Boxes) (Los Angeles)',
#  ' 91416',
#  ' 91426',
#  ' Fair Oaks Ranch',
#  ' 91387',
#  ' Fairfax (Los Angeles)',
#  ' 90036',
#  ' Fairmont',
#  ' 93536',
#  ' Farmers Market (Los Angeles)',
#  ' 90036',
#  ' Florence-Graham',
#  ' South Los Angeles (Los Angeles)',
#  ' 90001',
#  ' Fuller Theological Seminary (Pasadena)',
#  ' 91182',
#  ' Gardena',
#  ' 90247',
#  ' 90248',
#  ' 90249',
#  ' Glassell Park (Los Angeles)',
#  ' 90065',
#  ' Glendale',
#  ' 91201',
#  ' 91202',
#  ' 91203',
#  ' 91206',
#  ' 91207',
#  ' 91208',
#  ' 91214',
#  ' 91224',
#  ' Glendale (Glendale Galleria PO Boxes)',
#  ' 91210',
#  ' Glendale (PO Boxes)',
#  ' 91209',
#  ' 91221',
#  ' 91222',
#  ' 91225',
#  ' 91226',
#  ' Glendale (Tropico)',
#  ' 91204',
#  ' 91205',
#  ' Glendale (Verdugo City)',
#  ' 91046',
#  ' Glendale Galleria &amp; Americana at Brand (Glendale)',
#  ' 91210',
#  ' Glendora',
#  ' 91740',
#  ' 91741',
#  ' Glenoaks (Burbank)',
#  ' 91504',
#  ' Granada Hills (Los Angeles)',
#  ' 91344',
#  ' Granada Hills (PO Boxes) (Los Angeles)',
#  ' 91394',
#  ' Green Valley',
#  ' 91350',
#  ' 91390',
#  ' Griffith Park (Los Angeles)',
#  ' 90027',
#  ' Hacienda Heights',
#  ' 91745',
#  ' Hancock Park (Los Angeles)',
#  ' 90004',
#  ' 90005',
#  ' 90020',
#  ' Hansen Hills (Los Angeles)',
#  ' 91331',
#  ' Harbor City (Los Angeles)',
#  ' 90710',
#  ' Harbor Gateway/Shoestring (Los Angeles)',
#  ' 90061',
#  ' 90247',
#  ' 90248',
#  ' 90501',
#  ' 90502',
#  ' Harvard Heights (Los Angeles)',
#  ' 90006',
#  ' Hawaiian Gardens',
#  ' 90716',
#  ' Hawthorne (Holly Park)',
#  ' 90250',
#  ' Hawthorne (PO Boxes)',
#  ' 90251',
#  ' Hermosa Beach',
#  ' 90254',
#  ' Hi Vista',
#  ' 93535',
#  ' Hidden Hills',
#  ' 91302',
#  ' Highland Park (Los Angeles)',
#  ' 90042',
#  ' Highland Park (PO Boxes) (Los Angeles)',
#  ' 90050',
#  ' Holly Park (Hawthorne)',
#  ' 90250',
#  ' Hollywood (Los Angeles)',
#  ' 90027',
#  ' 90028',
#  ' 90038',
#  ' 90046',
#  ' 90068',
#  ' 90069',
#  ' Hollywood (PO Boxes) (Los Angeles)',
#  ' 90072',
#  ' 90078',
#  ' 90093',
#  ' Huntington Park',
#  ' 90255',
#  ' Hyde Park (Los Angeles)',
#  ' 90043',
#  ' Industry',
#  ' City of',
#  ' 90601',
#  ' 91744',
#  ' 91748',
#  ' 91789',
#  ' Industry',
#  ' City of (PO Boxes)',
#  ' 91714',
#  ' 91715',
#  ' 91716',
#  ' Inglewood',
#  ' 90301',
#  ' 90302',
#  ' 90303',
#  ' 90304',
#  ' 90305',
#  ' Inglewood (PO Boxes)',
#  ' 90306',
#  ' 90307',
#  ' 90308',
#  ' 90309',
#  ' 90310',
#  ' 90311',
#  ' 90312',
#  ' Irwindale',
#  ' 91010',
#  ' 91702',
#  ' 91706',
#  ' Jefferson Park (Los Angeles)',
#  ' 90018',
#  ' Juniper Hills',
#  ' 93543',
#  ' 93553',
#  ' Kagel Canyon',
#  ' 91342',
#  ' Koreatown (Los Angeles)',
#  ' 90005',
#  ' 90006',
#  ' La Cañada Flintridge',
#  ' 91011',
#  ' La Cañada Flintridge (PO Boxes)',
#  ' 91012',
#  ' La Crescenta',
#  ' 91214',
#  ' La Crescenta (PO Boxes)',
#  ' 91224',
#  ' La Habra Heights',
#  ' 90631',
#  ' La Mirada',
#  ' 90638',
#  ' La Mirada (Biola University)',
#  ' 90639',
#  ' La Mirada (PO Boxes)',
#  ' 90637',
#  ' La Puente',
#  ' 91744',
#  ' La Puente (PO Boxes)',
#  ' 91747',
#  ' 91749',
#  ' La Tuna Canyon (Los Angeles)',
#  ' 91352',
#  ' La Verne',
#  ' 91750',
#  ' Ladera Heights',
#  ' 90056',
#  ' Lake Balboa (Los Angeles)',
#  ' 91406',
#  ' Lake Hughes',
#  ' 93532',
#  ' Lake Los Angeles',
#  ' 93535',
#  ' 93550',
#  ' 93591',
#  ' Lake View Terrace (Los Angeles)',
#  ' 91342',
#  ' Lakewood',
#  ' 90712',
#  ' 90713',
#  ' 90715',
#  ' Lakewood (PO Boxes)',
#  ' 90711',
#  ' 90714',
#  ' Lancaster',
#  ' 93534',
#  ' 93535',
#  ' 93536',
#  ' 93586',
#  ' Lancaster (PO Boxes)',
#  ' 93539',
#  ' 93584',
#  ' Lawndale',
#  ' 90260',
#  ' Lawndale Federal Bldg',
#  ' 90261',
#  ' Leimert Park (Los Angeles)',
#  ' 90008',
#  ' 90018',
#  ' Lennox',
#  ' 90304',
#  ' Leona Valley',
#  ' 93532',
#  ' 93551',
#  ' Lincoln Heights',
#  ' Montecito Hieghts (Los Angeles)',
#  ' 90031',
#  ' Littlerock',
#  ' 93543',
#  ' Llano',
#  ' 93544',
#  ' Lockheed Advanced Dev Co (Palmdale)',
#  ' 93599',
#  ' Lomita',
#  ' 90717',
#  ' Long Beach',
#  ' 90802',
#  ' 90806',
#  ' 90808',
#  ' 90810',
#  ' 90813',
#  ' 90814',
#  ' 90815',
#  ' 90822',
#  ' 90740 (overlaps Orange County)',
#  ' Long Beach (AARP Pharmacy)',
#  ' 90848',
#  ' Long Beach (AARP)',
#  ' 90847',
#  ' Long Beach (Belmont Shore PO Boxes)',
#  ' 90853',
#  ' Long Beach (Belmont Shore',
#  ' Marina',
#  ' Naples)',
#  ' 90803',
#  ' Long Beach (Bixby Knolls)',
#  ' 90807',
#  ' Long Beach (Boeing)',
#  ' 90846',
#  ' Long Beach (California State Univ Long Beach)',
#  ' 90840',
#  ' Long Beach (Dept. of Gas &amp; Water)',
#  ' 90842',
#  ' Long Beach (East Long Beach)',
#  ' 90804',
#  ' Long Beach (LA International Service Center)',
#  ' 90899',
#  ' Long Beach (Non-Geographic Zip Code Within 90802)',
#  ' 90834',
#  ' Long Beach (North Long Beach)',
#  ' 90805',
#  ' Long Beach (PO Boxes)',
#  ' 90801',
#  ' 90809',
#  ' Long Beach (Press Telegram)',
#  ' 90844',
#  ' Long Beach (World Trade Center PO Boxes)',
#  ' 90832',
#  ' Long Beach (World Trade Center)',
#  ' 90831',
#  ' 90833',
#  ' 90835',
#  ' Los Angeles (Arleta)',
#  ' 91331',
#  ' Los Angeles (Arlington Heights)',
#  ' 90019',
#  ' Los Angeles (Atwater Village)',
#  ' 90039',
#  ' Los Angeles (Baldwin Hills)',
#  ' 90008',
#  ' Los Angeles (Bel Air Estates)',
#  ' 90077',
#  ' Los Angeles (Bel Air Estates)',
#  ' 90049',
#  ' Los Angeles (Beverly Glen)',
#  ' 90077',
#  ' Los Angeles (Brentwood)',
#  ' 90049',
#  ' Los Angeles (Byzantine-Latino Quarter)',
#  ' 90006',
#  ' Los Angeles (Canoga Park)',
#  ' 91304',
#  ' Los Angeles (Castellemare)',
#  ' 90272',
#  ' Los Angeles (Cheviot Hills)',
#  ' 90064',
#  ' Los Angeles (Chinatown)',
#  ' 90012',
#  ' Los Angeles (Country Club Park)',
#  ' 90019',
#  ' Los Angeles (Crenshaw)',
#  ' 90008',
#  ' Los Angeles (Cypress Park)',
#  ' 90065',
#  ' Los Angeles (Downtown Arts District)',
#  ' 90014',
#  ' Los Angeles (Downtown Bunker Hill)',
#  ' 90017',
#  ' 90071',
#  ' Los Angeles (Downtown City West)',
#  ' 90017',
#  ' Los Angeles (Downtown Civic Center)',
#  ' 90012',
#  ' Los Angeles (Downtown Historic Core)',
#  ' 90014',
#  ' Los Angeles (Dowtown Fashion District)',
#  ' 90013',
#  ' 90015',
#  ' 90079',
#  ' Los Angeles (Echo Park)',
#  ' 90026',
#  ' Los Angeles (El Sereno',
#  ' Monterey Hills',
#  ' University Hills)',
#  ' 90032',
#  ' Los Angeles (Elysian Valley)',
#  ' 90039',
#  ' Los Angeles (Fairfax)',
#  ' 90036',
#  ' Los Angeles (Florence-Graham',
#  ' 90001',
#  ' Los Angeles (Glassell Park)',
#  ' 90065',
#  ' Los Angeles (Griffith Park)',
#  ' 90027',
#  ' Los Angeles (Hancock Park)',
#  ' 90004',
#  ' 90020',
#  ' Los Angeles (Hansen Hills)',
#  ' 91331',
#  ' Los Angeles (Harbor Gateway/Shoestring)',
#  ' 90061',
#  ' 90247',
#  ' 90248',
#  ' 90501',
#  ' 90502',
#  ' Los Angeles (Harvard Heights)',
#  ' 90006',
#  ' Los Angeles (Hollywood)',
#  ' 90027',
#  ' 90028',
#  ' 90038',
#  ' 90046',
#  ' 90068',
#  ' 90069',
#  ' Los Angeles (Hyde Park)',
#  ' 90043',
#  ' Los Angeles (Jefferson Park)',
#  ' 90018',
#  ' Los Angeles (Koreatown)',
#  ' 90006',
#  ' Los Angeles (La Tuna Canyon)',
#  ' 91352',
#  ' Los Angeles (Lake View Terrace)',
#  ' 91342',
#  ' Los Angeles (Leimert Park)',
#  ' 90008',
#  ' Los Angeles (Leimert Park)',
#  ' 90018',
#  ' Los Angeles (Little Tokyo)',
#  ' 90012',
#  ' Los Angeles (Los Angeles International Airport)',
#  ' 90045',
#  ' Los Angeles (Los Feliz)',
#  ' 90027',
#  ' Los Angeles (Melrose)',
#  ' 90036',
#  ' 90046',
#  ' 90069',
#  ' Los Angeles (Mid-City)',
#  ' 90019',
#  ' Los Angeles (Mid-City West)',
#  ' 90048',
#  ' Los Angeles (Miracle Mile)',
#  ' 90036',
#  ' Los Angeles (Mission Hills)',
#  ' 91340',
#  ' 91345',
#  ' Los Angeles (Mission Hills PO Boxes)',
#  ' 91346',
#  ' 91395',
#  ' Los Angeles (Monterey Hills)',
#  ' 90032',
#  ' Los Angeles (Mt Olympus)',
#  ' 90046',
#  ' Los Angeles (Mt Washington)',
#  ' 90065',
#  ' Los Angeles (North Hills)',
#  ' 91343',
#  ' Los Angeles (North Hills PO Boxes)',
#  ' 91393',
#  ' Los Angeles (North Hollywood)',
#  ' 91601',
#  ' 91602',
#  ' 91605',
#  ' 91606',
#  ' 91607',
#  ' Los Angeles (North Hollywood PO Boxes)',
#  ' 91603',
#  ' 91609',
#  ' 91614',
#  ' 91615',
#  ' 91616',
#  ' 91618',
#  ' Los Angeles (North Hollywood/US Purchasing Exchange)',
#  ' 91611',
#  ' 91612',
#  ' Los Angeles (Northridge)',
#  ' 91324',
#  ' 91325',
#  ' 91326',
#  ' Los Angeles (Northridge PO Boxes)',
#  ' 91327',
#  ' 91328',
#  ' Los Angeles (Northridge/JB Lansing Co)',
#  ' 91329',
#  ' Los Angeles (Pacific Highlands)',
#  ' 90272',
#  ' Los Angeles (Pacific Palisades)',
#  ' 90272',
#  ' Los Angeles (Pacoima)',
#  ' 91331',
#  ' Los Angeles (Pacoima PO Boxes)',
#  ' 91333',
#  ' 91334',
#  ' Los Angeles (Palms)',
#  ' 90034',
#  ' Los Angeles (Panorama City)',
#  ' 91402',
#  ' Los Angeles (Panorama City PO Boxes)',
#  ' 91412',
#  ' Los Angeles (Park La Brea)',
#  ' 90036',
#  ' Los Angeles (Pico Heights)',
#  ' 90006',
#  ' Los Angeles (Pierce College)',
#  ' 91371',
#  ' Los Angeles (Playa del Rey)',
#  ' 90293',
#  ' Los Angeles (Playa del Rey PO Boxes)',
#  ' 90296',
#  ' Los Angeles (Playa Vista)',
#  ' 90094',
#  ' Los Angeles (Porter Ranch)',
#  ' 91326',
#  ' Los Angeles (Rampart Village)',
#  ' 90004',
#  ' Los Angeles (Rancho Park)',
#  ' 90064',
#  ' Los Angeles (Reseda)',
#  ' 91335',
#  ' Los Angeles (Reseda PO Boxes)',
#  ' 91337',
#  ' Los Angeles (San Pedro)',
#  ' 90731',
#  ' 90732',
#  ' Los Angeles (San Pedro PO Boxes)',
#  ' 90733',
#  ' 90734',
#  ' Los Angeles (Sawtelle)',
#  ' 90025',
#  ' Los Angeles (Shadow Hills)',
#  ' 91040',
#  ' Los Angeles (Sherman Oaks)',
#  ' 91403',
#  ' 91423',
#  ' Los Angeles (Sherman Oaks',
#  ' Van Nuys PO Boxes)',
#  ' 91413',
#  ' Los Angeles (Sherman Village)',
#  ' 91607',
#  ' Los Angeles (Silver Lake)',
#  ' 90026',
#  ' 90039',
#  ' Los Angeles (South Los Angeles)',
#  ' 90037',
#  ' 90044',
#  ' 90047',
#  '90062',
#  ' Los Angeles (South Los Angeles PO Boxes)',
#  ' 90051',
#  ' 90052',
#  ' 90054',
#  ' 90082',
#  ' 90087',
#  ' Los Angeles (South Park-North)',
#  ' 90015',
#  ' 90017',
#  ' Los Angeles (South Park-South)',
#  ' 90015',
#  ' Los Angeles (Southeast Los Angeles)',
#  ' 90002',
#  ' 90003',
#  ' 90007',
#  ' 90011',
#  ' 90037',
#  ' 90058',
#  ' Los Angeles (Studio City)',
#  ' 91602',
#  ' 91604',
#  ' Los Angeles (Sun Valley)',
#  ' 91352',
#  ' Los Angeles (Sun Valley PO Boxes)',
#  ' 91353',
#  ' Los Angeles (Sunland)',
#  ' 91040',
#  ' Los Angeles (Sunland PO Boxes)',
#  ' 91041',
#  ' Los Angeles (Sylmar)',
#  ' 91340',
#  ' 91342',
#  ' Los Angeles (Sylmar PO Boxes)',
#  ' 91392',
#  ' Los Angeles (Tarzana)',
#  ' 91356',
#  ' Los Angeles (Tarzana PO Boxes)',
#  ' 91357',
#  ' Los Angeles (Terminal Island)',
#  ' 90731',
#  ' Los Angeles (Toluca Lake)',
#  ' 91602',
#  ' Los Angeles (Toluca Lake PO Boxes)',
#  ' 91610',
#  ' Los Angeles (Toluca Terrace)',
#  ' 91601',
#  ' Los Angeles (Topanga State Park)',
#  ' 90272',
#  ' Los Angeles (Tujunga)',
#  ' 91042',
#  ' Los Angeles (Tujunga PO Boxes)',
#  ' 91043',
#  ' Los Angeles (University of California Los Angeles)',
#  ' 90095',
#  ' Los Angeles (University of Southern California)',
#  ' 90089',
#  ' Los Angeles (University Park)',
#  ' 90007',
#  ' Los Angeles (Valley Glen)',
#  ' 91401',
#  ' 91405',
#  ' 91606',
#  ' 91607',
#  ' Los Angeles (Valley Village)',
#  ' 91607',
#  ' Los Angeles (Valley Village PO Boxes)',
#  ' 91617',
#  ' Los Angeles (Van Nuys)',
#  ' 91401',
#  ' 91405',
#  ' 91406',
#  ' 91411',
#  ' Los Angeles (Van Nuys PO Boxes)',
#  ' 91404',
#  ' 91407',
#  ' 91408',
#  ' 91409',
#  ' 91410',
#  ' Los Angeles (Van Nuys/Blue Cross of Southern California)',
#  ' 91470',
#  ' Los Angeles (Van Nuys/Business Reply)',
#  ' 91499',
#  ' Los Angeles (Van Nuys/Deluxe Check)',
#  ' 91482',
#  ' Los Angeles (Van Nuys/US Purchasing Corp)',
#  ' 91496',
#  ' Los Angeles (Van Nuys/US Purchasing Exchange)',
#  ' 91495',
#  ' Los Angeles (Venice)',
#  ' 90291',
#  ' Los Angeles (Venice PO Boxes)',
#  ' 90294',
#  ' Los Angeles (View Park)',
#  ' 90043',
#  ' Los Angeles (Virgil Village)',
#  ' 90004',
#  ' Los Angeles (Watts)',
#  ' 90002',
#  ' 90059',
#  ' Los Angeles (Watts PO Boxes)',
#  ' 90060',
#  ' Los Angeles (Wells Fargo)',
#  ' 90084',
#  ' 90088',
#  ' Los Angeles (West Adams)',
#  ' 90016',
#  ' Los Angeles (West Beverly)',
#  ' 90048',
#  ' Los Angeles (West Fairfax)',
#  ' 90035',
#  ' Los Angeles (West Hills)',
#  ' 91304',
#  ' 91307',
#  ' Los Angeles (West Los Angeles)',
#  ' 90025',
#  ' Los Angeles (West Toluca Lake)',
#  ' 91602',
#  ' Los Angeles (Westchester)',
#  ' 90045',
#  ' Los Angeles (Westchester PO Boxes)',
#  ' 90083',
#  ' Los Angeles (Western Wilton)',
#  ' 90020',
#  ' Los Angeles (Westlake)',
#  ' 90057',
#  ' Los Angeles (Westwood)',
#  ' 90024',
#  ' Los Angeles (Wilmington)',
#  ' 90744',
#  ' Los Angeles (Wilmington PO Boxes)',
#  ' 90748',
#  ' Los Angeles (Wilshire Center)',
#  ' 90004',
#  ' 90005',
#  ' 90010',
#  ' 90020',
#  ' Los Angeles (Wilshire Center PO Boxes)',
#  ' 90070',
#  ' 90075',
#  ' 90076',
#  ' Los Angeles (Wilshire Park)',
#  ' 90005',
#  ' Los Angeles (Windsor Hills)',
#  ' 90043',
#  ' Los Angeles (Windsor Square)',
#  ' 90004',
#  ' 90005',
#  ' 90010',
#  ' 90020',
#  ' Los Angeles (Winnetka)',
#  ' 91306',
#  ' Los Angeles (Winnetka PO Boxes)',
#  ' 91396',
#  ' Los Angeles (Woodland Hills)',
#  ' 91302',
#  ' 91303',
#  ' 91364',
#  ' 91367',
#  ' Los Angeles (Woodland Hills PO Boxes)',
#  ' 91365',
#  ' 91372',
#  ' Los Angeles Dodgers (Los Angeles)',
#  ' 90090',
#  ' Los Angeles International Airport (PO Boxes) (Los Angeles)',
#  ' 90009',
#  ' 90080',
#  ' Los Angeles International Airport',
#  ' Westchester (Los Angeles)',
#  ' 90045',
#  ' Los Feliz (Los Angeles)',
#  ' 90027',
#  ' Los Nietos',
#  ' 90606',
#  ' Los Nietos (PO Boxes)',
#  ' 90610',
#  ' Lynwood',
#  ' 90262',
#  ...]

# %% [markdown]
# Here we have the bulk of our data cleaning! See the comments for more information on what is happening but the basic idea is to take a list of strings and turn some of the items into int, while also getting rid of some extra zip codes we wont be using and fix a couple formatting problems. We will also be grabbing some latitude and longitude data while we are at it

# %%
#remove spaces
s1 = [s.strip(' ') for s in s]
#create empty list
a = []
nomi = pgeocode.Nominatim('US')
#create variable to use for itteration
cityNumber = 0
#create boolean variables for determining if last itterated was a string or int
lastWasZIP = False
lastwasletter = False
#for loop to convert zip codes to int and group city with zip code
for x in s1:
  if not x[1].isdigit() and lastwasletter == False: #if current item is NOT a number AND last item WAS
    if cityNumber == 0:                                 #if city number is 0->
      a.append([x[1:],10000,0,0])                           #append with 10000 for easy to spot error catching and remove 1st "["
      cityNumber = cityNumber + 1                       #move to next variable
      lastwasletter = True                              #last item WAS a letter
    else:
      if not str(a[cityNumber-1][0][0:5]) in x:         #if not a str that matches previous cities 1st 6 characters
        a.append([x,10000,0,0])                             #append with 10000 for easy to spot error catching
        cityNumber = cityNumber + 1                     #move to next variable
        lastWasZIP = False                              #last item was NOT a number
        lastwasletter = True                            #last item WAS a letter
  elif lastWasZIP == False and x[1].isdigit():      #if last item was NOT a number AND current IS
      if x[len(x)-1] != "]":                            
        a[cityNumber-1][1] = int(x)                     #replace 10000 with int version or this line of x     
        a[cityNumber-1][2] = nomi.query_postal_code(int(x)).latitude
        a[cityNumber-1][3] = nomi.query_postal_code(int(x)).longitude
        lastWasZIP = True
        lastwasletter = False
      else:
        a[cityNumber-1][1] = int(x[:-1])                #replace 10000 with int version without last character of x
        a[cityNumber-1][2] = nomi.query_postal_code(int(x[:-1])).latitude
        a[cityNumber-1][3] = nomi.query_postal_code(int(x[:-1])).longitude
        lastWasZIP = True
        lastwasletter = False

# %%
a
# Out:
# [['Acton', 93510, 34.4835, -118.1959],
#  ['Agoura Hills', 91301, 34.1227, -118.7573],
#  ['Agua Dulce', 91390, 34.4684, -118.5261],
#  ['Alhambra', 91801, 34.0914, -118.1293],
#  ['Altadena', 91001, 34.1912, -118.1392],
#  ['Americana at Brand &amp; Glendale Galleria (Glendale)',
#   91210,
#   34.1425,
#   -118.2551],
#  ['Arcadia', 91006, 34.1324, -118.0264],
#  ['Arleta (Los Angeles)', 91331, 34.2556, -118.4208],
#  ['Arlington Heights (Los Angeles)', 90019, 34.0482, -118.3343],
#  ['Artesia', 90701, 33.8654, -118.0731],
#  ['Athens', 90044, 33.9551, -118.2901],
#  ['Atwater Village (Los Angeles)', 90039, 34.1121, -118.2594],
#  ['Avalon (PO Boxes)', 90704, 33.332, -118.3437],
#  ['Avocado Heights', 91746, 34.0443, -117.9862],
#  ['Azusa', 91010, 34.1407, -117.9567],
#  ['Baldwin Hills (Los Angeles)', 90008, 34.0116, -118.3411],
#  ['Bassett', 91746, 34.0443, -117.9862],
#  ['Bel Air Estates (Los Angeles)', 90049, 34.066, -118.47399999999999],
#  ['Beverly Glen (Los Angeles)', 90077, 34.1112, -118.4502],
#  ['Bell', 90201, 33.9653, -118.1515],
#  ['Belmont Shore (Long Beach)', 90803, 33.7619, -118.1341],
#  ['Beverly Glen', 90077, 34.1112, -118.4502],
#  ['Biola University (La Mirada)', 90639, 33.9058, -118.0182],
#  ['Bixby Knolls (Long Beach)', 90807, 33.8315, -118.1811],
#  ['Bouquet Canyon', 91350, 34.4336, -118.5007],
#  ['Box Canyon', 91304, 34.2197, -118.6111],
#  ['Boyle Heights (Los Angeles)', 90033, 34.0487, -118.2084],
#  ['Bradbury', 91008, 34.149, -117.9644],
#  ['Brentwood (Los Angeles)', 90049, 34.066, -118.47399999999999],
#  ['Burbank', 91501, 34.1862, -118.3009],
#  ['Bureau of the Census (Pomona)', 91797, nan, nan],
#  ['Byzantine-Latino Quarter (Los Angeles)', 90006, 34.0493, -118.2917],
#  ['Calabasas', 91302, 34.1419, -118.6641],
#  ['California Institute of Technology (Pasadena)', 91125, 34.1478, -118.1445],
#  ['Camino College (Torrance)', 90506, 33.7866, -118.2987],
#  ['Canoga Park (Los Angeles)', 91303, 34.1993, -118.5983],
#  ['Canyon Country (PO Boxes) (Santa Clarita)',
#   91386,
#   34.4233,
#   -118.47200000000001],
#  ['Carson', 90745, 33.823, -118.2684],
#  ['Castaic', 91310, 34.4889, -118.6229],
#  ['Catalina Island (PO Boxes)', 90704, 33.332, -118.3437],
#  ['Castellemare (Los Angeles)', 90272, 34.0481, -118.5265],
#  ['Century City (Los Angeles)', 90067, 34.0551, -118.4095],
#  ['Cerritos', 90703, 33.8669, -118.0686],
#  ['Charter Oak', 91724, 34.0938, -117.85600000000001],
#  ['Chatsworth (Los Angeles)', 91311, 34.2583, -118.5914],
#  ['Cheviot Hills (Los Angeles)', 90064, 34.0353, -118.4259],
#  ['Chinatown (Los Angeles)', 90012, 34.0614, -118.2385],
#  ['Citibank (Los Angeles)', 90189, 34.0515, -118.2559],
#  ['City Ranch', 93551, 34.6017, -118.23100000000001],
#  ['Claremont', 91711, 34.1092, -117.7183],
#  ['Commerce', 90040, 33.9909, -118.1532],
#  ['East Los Angeles', 90023, 34.0245, -118.1975],
#  ['Compton', 90220, 33.8748, -118.2402],
#  ['Cornell', 91301, 34.1227, -118.7573],
#  ['Country Club Park (Los Angeles)', 90019, 34.0482, -118.3343],
#  ['Covina', 91722, 34.0972, -117.9065],
#  ['Crenshaw (Los Angeles)', 90008, 34.0116, -118.3411],
#  ['Crystalaire', 93544, 34.493, -117.7543],
#  ['Cudahy', 90201, 33.9653, -118.1515],
#  ['Culver City', 90066, 34.003, -118.4298],
#  ['Cypress Park (Los Angeles)', 90065, 34.1073, -118.2266],
#  ['Del Sur', 93536, 34.7471, -118.3687],
#  ['Diamond Bar', 91765, 34.0066, -117.8098],
#  ['Dominguez', 90810, 33.8193, -118.2325],
#  ['Downey', 90240, 33.9581, -118.1174],
#  ['Downtown Arts District (Los Angeles)', 90012, 34.0614, -118.2385],
#  ['Duarte', 91010, 34.1407, -117.9567],
#  ['Eagle Rock (Los Angeles)', 90041, 34.1339, -118.2082],
#  ['East Hollywood (Los Angeles)', 90029, 34.09, -118.2944],
#  ['City of Commerce', 90023, 34.0245, -118.1975],
#  ['East Rancho Dominguez', 90221, 33.8796, -118.2168],
#  ['Echo Park (Los Angeles)', 90026, 34.0766, -118.2646],
#  ['Edwards AFB (Portion in LA County)', 93523, 34.9261, -117.9351],
#  ['El Monte', 91731, 34.0791, -118.0371],
#  ['El Segundo', 90245, 33.9243, -118.4119],
#  ['Monterey Hills', 90032, 34.0818, -118.1753],
#  ['Elizabeth Lake', 93532, 34.6847, -118.5442],
#  ['Elysian Valley (Los Angeles)', 90039, 34.1121, -118.2594],
#  ['Encino (Los Angeles)', 91316, 34.1655, -118.5175],
#  ['Fair Oaks Ranch', 91387, 34.4132, -118.426],
#  ['Fairfax (Los Angeles)', 90036, 34.0699, -118.3492],
#  ['Fairmont', 93536, 34.7471, -118.3687],
#  ['Farmers Market (Los Angeles)', 90036, 34.0699, -118.3492],
#  ['Florence-Graham', 90001, 33.9731, -118.2479],
#  ['Fuller Theological Seminary (Pasadena)', 91182, 34.1478, -118.1445],
#  ['Gardena', 90247, 33.8925, -118.2961],
#  ['Glassell Park (Los Angeles)', 90065, 34.1073, -118.2266],
#  ['Glendale', 91201, 34.1716, -118.2899],
#  ['Glenoaks (Burbank)', 91504, 34.2001, -118.3264],
#  ['Granada Hills (Los Angeles)', 91344, 34.2771, -118.4992],
#  ['Green Valley', 91350, 34.4336, -118.5007],
#  ['Griffith Park (Los Angeles)', 90027, 34.104, -118.2925],
#  ['Hacienda Heights', 91745, 33.9977, -117.9652],
#  ['Hancock Park (Los Angeles)', 90004, 34.0762, -118.3029],
#  ['Hansen Hills (Los Angeles)', 91331, 34.2556, -118.4208],
#  ['Harbor City (Los Angeles)', 90710, 33.797, -118.2991],
#  ['Harvard Heights (Los Angeles)', 90006, 34.0493, -118.2917],
#  ['Hawaiian Gardens', 90716, 33.8296, -118.073],
#  ['Hawthorne (Holly Park)', 90250, 33.9143, -118.3493],
#  ['Hermosa Beach', 90254, 33.8643, -118.3955],
#  ['Hi Vista', 93535, 34.7131, -117.8783],
#  ['Hidden Hills', 91302, 34.1419, -118.6641],
#  ['Highland Park (Los Angeles)', 90042, 34.1145, -118.1929],
#  ['Holly Park (Hawthorne)', 90250, 33.9143, -118.3493],
#  ['Huntington Park', 90255, 33.9769, -118.2161],
#  ['Hyde Park (Los Angeles)', 90043, 33.9871, -118.3321],
#  ['Industry', 90601, 34.0011, -118.0371],
#  ['City of (PO Boxes)', 91714, 34.0197, -117.9587],
#  ['Inglewood', 90301, 33.955, -118.3556],
#  ['Irwindale', 91010, 34.1407, -117.9567],
#  ['Jefferson Park (Los Angeles)', 90018, 34.029, -118.3152],
#  ['Juniper Hills', 93543, 34.4891, -117.9708],
#  ['Kagel Canyon', 91342, 34.3054, -118.4322],
#  ['Koreatown (Los Angeles)', 90005, 34.0585, -118.3012],
#  ['La Cañada Flintridge', 91011, 34.2217, -118.2051],
#  ['La Crescenta', 91214, 34.2316, -118.2457],
#  ['La Habra Heights', 90631, 33.9331, -117.9493],
#  ['La Mirada', 90638, 33.9067, -118.0101],
#  ['La Puente', 91744, 34.0289, -117.9373],
#  ['La Tuna Canyon (Los Angeles)', 91352, 34.2209, -118.3699],
#  ['La Verne', 91750, 34.1159, -117.7708],
#  ['Ladera Heights', 90056, 33.9853, -118.3707],
#  ['Lake Balboa (Los Angeles)', 91406, 34.2006, -118.4868],
#  ['Lakewood', 90712, 33.8512, -118.1457],
#  ['Lancaster', 93534, 34.6909, -118.1491],
#  ['Lawndale', 90260, 33.8879, -118.351],
#  ['Leimert Park (Los Angeles)', 90008, 34.0116, -118.3411],
#  ['Lennox', 90304, 33.9379, -118.3586],
#  ['Leona Valley', 93532, 34.6847, -118.5442],
#  ['Lincoln Heights', 90031, 34.0783, -118.2113],
#  ['Littlerock', 93543, 34.4891, -117.9708],
#  ['Llano', 93544, 34.493, -117.7543],
#  ['Lockheed Advanced Dev Co (Palmdale)', 93599, 34.5794, -118.1165],
#  ['Lomita', 90717, 33.7938, -118.3172],
#  ['Long Beach', 90802, 33.7706, -118.182],
#  ['Marina', 90803, 33.7619, -118.1341],
#  ['Long Beach (Bixby Knolls)', 90807, 33.8315, -118.1811],
#  ['Los Angeles (Arleta)', 91331, 34.2556, -118.4208],
#  ['Monterey Hills', 90032, 34.0818, -118.1753],
#  ['Los Angeles (Elysian Valley)', 90039, 34.1121, -118.2594],
#  ['Van Nuys PO Boxes)', 91413, 34.1511, -118.4492],
#  ['Los Angeles (Sherman Village)', 91607, 34.1672, -118.3989],
#  ['Los Nietos', 90606, 33.9777, -118.0658],
#  ['Lynwood', 90262, 33.9241, -118.2013],
#  ['Malibu', 90265, 34.0402, -118.7351],
#  ['Manhattan Beach', 90266, 33.8896, -118.3996],
#  ['Mar Vista (Los Angeles)', 90066, 34.003, -118.4298],
#  ['Marina (Long Beach)', 90803, 33.7619, -118.1341],
#  ['Maywood', 90270, 33.989000000000004, -118.1877],
#  ['Melrose (Los Angeles)', 90036, 34.0699, -118.3492],
#  ['Metler Valley', 93536, 34.7471, -118.3687],
#  ['Mid-City (Los Angeles)', 90019, 34.0482, -118.3343],
#  ['Mint Canyon', 91350, 34.4336, -118.5007],
#  ['Miracle Mile (Los Angeles)', 90036, 34.0699, -118.3492],
#  ['Mission Hills (Los Angeles)', 91340, 34.2875, -118.4352],
#  ['Monrovia', 91010, 34.1407, -117.9567],
#  ['Monte Nido', 91302, 34.1419, -118.6641],
#  ['Lincoln Heights (Los Angeles)', 90031, 34.0783, -118.2113],
#  ['Monterey Hills', 90032, 34.0818, -118.1753],
#  ['Montrose', 91020, 34.2114, -118.2305],
#  ['Mount Baldy (Portion in LA County)', 91759, 34.2361, -117.6601],
#  ['Mt. Washington (Los Angeles)', 90065, 34.1073, -118.2266],
#  ['Naples (Long Beach)', 90803, 33.7619, -118.1341],
#  ['Neenach', 93536, 34.7471, -118.3687],
#  ['Newhall (PO Boxes) (Santa Clarita)', 91322, 34.3847, -118.5309],
#  ['North Hills (Los Angeles)', 91343, 34.2366, -118.4758],
#  ['Norwalk', 90650, 33.9056, -118.0818],
#  ['Ocean Park (Santa Monica)', 90405, 34.01, -118.4717],
#  ['Pacific Highlands', 90272, 34.0481, -118.5265],
#  ['Pacoima (Los Angeles)', 91331, 34.2556, -118.4208],
#  ['Palmdale', 93550, 34.4133, -118.0917],
#  ['Palms (Los Angeles)', 90034, 34.029, -118.4005],
#  ['Palos Verdes Estates', 90274, 33.7669, -118.3806],
#  ['Panorama City (Los Angeles)', 91402, 34.2262, -118.447],
#  ['Paramount', 90723, 33.8969, -118.1632],
#  ['Park La Brea (Los Angeles)', 90036, 34.0699, -118.3492],
#  ['Pasadena', 91101, 34.1468, -118.1391],
#  ['Pearblossom', 93553, 34.4225, -117.9055],
#  ['Pepperdine University (Malibu)', 90263, 34.005, -118.8101],
#  ['Phillips Ranch (Pomona)', 91766, 34.0418, -117.7569],
#  ['Pico Heights (Los Angeles)', 90006, 34.0493, -118.2917],
#  ['Pierce College (Woodland Hills', 91371, 34.1683, -118.6059],
#  ['Playa del Rey (Los Angeles)', 90293, 33.9577, -118.4373],
#  ['Pomona', 91767, 34.0812, -117.7362],
#  ['Porter Ranch (Los Angeles)', 91326, 34.2619, -118.58200000000001],
#  ['Quartz Hill', 93536, 34.7471, -118.3687],
#  ['Rampart Village (Los Angeles)', 90004, 34.0762, -118.3029],
#  ['Rancho Dominguez', 90220, 33.8748, -118.2402],
#  ['Redondo Beach', 90277, 33.8307, -118.3832],
#  ['Reseda (Los Angeles)', 91335, 34.2007, -118.5391],
#  ['Rolling Hills Estates', 90275, 33.7515, -118.367],
#  ['Roosevelt Corner', 93535, 34.7131, -117.8783],
#  ['Rosemead', 91770, 34.0658, -118.0853],
#  ['Rosewood', 90222, 33.9099, -118.2357],
#  ['Rowland Heights', 91748, 33.9818, -117.8969],
#  ['San Dimas', 91773, 34.1023, -117.8169],
#  ['San Fernando', 91340, 34.2875, -118.4352],
#  ['San Gabriel', 91775, 34.1155, -118.0857],
#  ['San Marino', 91108, 34.1207, -118.1117],
#  ['San Pedro (Los Angeles)', 90731, 33.7339, -118.2914],
#  ['Sandberg', 93532, 34.6847, -118.5442],
#  ['Santa Catalina Island (PO Boxes)', 90704, 33.332, -118.3437],
#  ['Sawtelle (Los Angeles)', 90025, 34.0447, -118.4487],
#  ['Shadow Hills (Los Angeles)', 91040, 34.2618, -118.3371],
#  ['Sherman Oaks (Los Angeles)', 91403, 34.1514, -118.4603],
#  ['Sierra Madre', 91024, 34.1651, -118.0519],
#  ['Signal Hill', 90755, 33.8029, -118.1677],
#  ['Silver Lake (Los Angeles)', 90026, 34.0766, -118.2646],
#  ['Sleepy Valley', 91350, 34.4336, -118.5007],
#  ['South El Monte', 91733, 34.0557, -118.0444],
#  ['Stevenson Ranch', 91381, 34.3775, -118.6131],
#  ['Studio City (Los Angeles)', 91602, 34.150999999999996, -118.3663],
#  ['Sun Valley (Los Angeles)', 91352, 34.2209, -118.3699],
#  ['Sunland (Los Angeles)', 91040, 34.2618, -118.3371],
#  ['Sunpark (Santa Monica)', 90405, 34.01, -118.4717],
#  ['Sylmar (Los Angeles)', 91340, 34.2875, -118.4352],
#  ['Tarzana (Los Angeles)', 91356, 34.1671, -118.5414],
#  ['Temple City', 91780, 34.1016, -118.0537],
#  ['Terminal Island (Los Angeles)', 90731, 33.7339, -118.2914],
#  ['Three Points', 93532, 34.6847, -118.5442],
#  ['Toluca Lake (Los Angeles)', 91602, 34.150999999999996, -118.3663],
#  ['Topanga', 90290, 34.1076, -118.6023],
#  ['Torrance', 90277, 33.8307, -118.3832],
#  ['West Carson', 90502, 33.8286, -118.292],
#  ['Tropico (Glendale)', 91204, 34.1379, -118.2599],
#  ['Tujunga (Los Angeles)', 91042, 34.2544, -118.2849],
#  ['Two Harbors', 90704, 33.332, -118.3437],
#  ['Universal City', 91608, 34.1383, -118.3528],
#  ['El Sereno', 90032, 34.0818, -118.1753],
#  ['University Park (Los Angeles)', 90007, 34.0294, -118.2871],
#  ['Val Verde', 91384, 34.4827, -118.6254],
#  ['Valencia (PO Boxes) (Santa Clarita)', 91380, 34.3917, -118.5426],
#  ['Valinda', 91744, 34.0289, -117.9373],
#  ['Valley Glen (Los Angeles)', 91401, 34.1802, -118.4324],
#  ['Valyermo', 93563, 34.3966, -117.7604],
#  ['Van Nuys (Los Angeles)', 91401, 34.1802, -118.4324],
#  ['Venice (Los Angeles)', 90291, 33.9938, -118.4635],
#  ['Verdugo City (Glendale)', 91046, 34.2114, -118.2395],
#  ['Vernon', 90058, 33.9994, -118.2133],
#  ['Veterans Administration', 90073, 33.7866, -118.2987],
#  ['View Park (Los Angeles)', 90043, 33.9871, -118.3321],
#  ['Virgil Village (Los Angeles)', 90004, 34.0762, -118.3029],
#  ['Walnut', 91789, 34.0183, -117.8546],
#  ['Walt Disney Co (Burbank)', 91521, 34.1808, -118.309],
#  ['Watts (Los Angeles)', 90002, 33.9497, -118.2462],
#  ['Wells Fargo (Los Angeles)', 90084, 34.0522, -118.2437],
#  ['West Adams (Los Angeles)', 90016, 34.0298, -118.3528],
#  ['Torrance', 90502, 33.8286, -118.292],
#  ['West Covina', 91790, 34.0673, -117.9366],
#  ['Westchester (PO Boxes) (Los Angeles)', 90083, 34.0522, -118.2437],
#  ['Los Angeles International Airport (Los Angeles)',
#   90045,
#   33.9631,
#   -118.3941],
#  ['Westlake Village', 91361, 34.1472, -118.8383],
#  ['Westwood (Los Angeles)', 90024, 34.0637, -118.4408],
#  ['Whittier', 90601, 34.0011, -118.0371],
#  ['Willowbrook', 90059, 33.9293, -118.2463],
#  ['Wilmington (Los Angeles)', 90744, 33.7855, -118.2645],
#  ['Wilshire Center (Los Angeles)', 90004, 34.0762, -118.3029],
#  ['Wilsona Gardens', 93535, 34.7131, -117.8783],
#  ['Windsor Hills (Los Angeles)', 90043, 33.9871, -118.3321],
#  ['Winnetka (Los Angeles)', 91306, 34.2092, -118.5749],
#  ['Woodland Hills (Los Angeles)', 91364, 34.1557, -118.6]]

# %% [markdown]
# Lets make it a data frame and have a look!

# %%
df = pd.DataFrame(a, columns =['Neighborhood', 'PostalCode', 'Latitude', 'Longitude'])
df
# Out:
#                       Neighborhood  PostalCode  Latitude  Longitude
# 0                            Acton       93510   34.4835  -118.1959
# 1                     Agoura Hills       91301   34.1227  -118.7573
# 2                       Agua Dulce       91390   34.4684  -118.5261
# 3                         Alhambra       91801   34.0914  -118.1293
# 4                         Altadena       91001   34.1912  -118.1392
# ..                             ...         ...       ...        ...
# 256  Wilshire Center (Los Angeles)       90004   34.0762  -118.3029
# 257                Wilsona Gardens       93535   34.7131  -117.8783
# 258    Windsor Hills (Los Angeles)       90043   33.9871  -118.3321
# 259         Winnetka (Los Angeles)       91306   34.2092  -118.5749
# 260   Woodland Hills (Los Angeles)       91364   34.1557  -118.6000
#
# [261 rows x 4 columns]

# %% [markdown]
# ## define a function to locate nearby venues
# ___

# %% [markdown]
# This will grab all the restaurants labeled "Mexican"

# %%
def getNearbyVenues(Neighborhood, PostalCode, Latitude, Longitude, radius=500):
    
    venues_list=[]
    for name, postalcode, lat, lng in zip(Neighborhood, PostalCode, Latitude, Longitude):
        if postalcode != 91797:
          #print(name)
            
          # create the API request URL
          url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
              CLIENT_ID, 
              CLIENT_SECRET, 
              VERSION, 
              lat, 
              lng, 
              radius, 
              LIMIT)
            
          # make the GET request
          #print(requests.get(url).json())
          results = requests.get(url).json()["response"]['groups'][0]['items']
          #print(results)
          #print("\n")
          # return only relevant information for each nearby venue
          for v in results:
            if v['venue']['categories'][0]['shortName'] == 'Mexican':
          #print("Here1\n")
              venues_list.append([(
               name, 
               lat, 
               lng, 
               v['venue']['name'], 
               v['venue']['location']['lat'], 
               v['venue']['location']['lng'],  
               v['venue']['categories'][0]['name'])])
    #print("Here2\n")
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Lat',
                  'Neighborhood Long',
                  'Venue', 
                  'Venue Lat',
                  'Venue Long',
                  'Venue Category']
    
    return(nearby_venues)

# %%
LA_venues = getNearbyVenues(Neighborhood=df['Neighborhood'],PostalCode=df['PostalCode'], Latitude=df['Latitude'],Longitude=df['Longitude'])

# %%
LA_venues
# Out:
#                         Neighborhood  ...      Venue Category
# 0                            Arcadia  ...  Mexican Restaurant
# 1    Arlington Heights (Los Angeles)  ...  Mexican Restaurant
# 2    Arlington Heights (Los Angeles)  ...  Mexican Restaurant
# 3                              Azusa  ...  Mexican Restaurant
# 4        Baldwin Hills (Los Angeles)  ...  Mexican Restaurant
# ..                               ...  ...                 ...
# 174                      Willowbrook  ...  Mexican Restaurant
# 175         Wilmington (Los Angeles)  ...  Mexican Restaurant
# 176    Wilshire Center (Los Angeles)  ...  Mexican Restaurant
# 177    Wilshire Center (Los Angeles)  ...  Mexican Restaurant
# 178           Winnetka (Los Angeles)  ...  Mexican Restaurant
#
# [179 rows x 7 columns]

# %%
LA_venues.head
# Out:
# <bound method NDFrame.head of                         Neighborhood  ...      Venue Category
# 0                            Arcadia  ...  Mexican Restaurant
# 1    Arlington Heights (Los Angeles)  ...  Mexican Restaurant
# 2    Arlington Heights (Los Angeles)  ...  Mexican Restaurant
# 3                              Azusa  ...  Mexican Restaurant
# 4        Baldwin Hills (Los Angeles)  ...  Mexican Restaurant
# ..                               ...  ...                 ...
# 174                      Willowbrook  ...  Mexican Restaurant
# 175         Wilmington (Los Angeles)  ...  Mexican Restaurant
# 176    Wilshire Center (Los Angeles)  ...  Mexican Restaurant
# 177    Wilshire Center (Los Angeles)  ...  Mexican Restaurant
# 178           Winnetka (Los Angeles)  ...  Mexican Restaurant
#
# [179 rows x 7 columns]>

# %% [markdown]
# ## map venues in relation to neighborhoods

# %% [markdown]
# Here is an interactive map that shows all the venues in blue and all the neighborhoods in red.

# %%
map_LA = folium.Map(location=[34.1324,-118.0264],zoom_start=10)

for ven_lat,ven_lng,neighborhood, venue in zip(LA_venues['Venue Lat'],LA_venues['Venue Long'],LA_venues['Neighborhood'],LA_venues['Venue']):
    label = '{}, {}'.format(venue, neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [ven_lat,ven_lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_LA)

for n_lat,n_lng,neighborhood in zip(LA_venues['Neighborhood Lat'],LA_venues['Neighborhood Long'],LA_venues['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [n_lat,n_lng],
    radius=3,
    popup=label,
    color='red',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.4,
    parse_html=False).add_to(map_LA)

map_LA
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_d0d2c7acbc1145e18d76884e792b6e26%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d0d2c7acbc1145e18d76884e792b6e26%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_d0d2c7acbc1145e18d76884e792b6e26%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_d0d2c7acbc1145e18d76884e792b6e26%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B34.1324%2C%20-118.0264%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_1fc41bd7e7a04995aace9e86f5fa9326%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20 ...
